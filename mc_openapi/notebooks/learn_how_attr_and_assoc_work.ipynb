# %% [markdown]
# ## How do Associations and Attributes Work?

# %%
from itertools import product
from operator import itemgetter

import yaml
from z3 import (And, Const, Consts, DatatypeSortRef, Exists, ForAll,
                FuncDeclRef, Implies, Model, Not, Or, Solver, sat, unsat)

from mc_openapi.doml_mc import DOMLVersion
from mc_openapi.doml_mc.intermediate_model.metamodel import (
    parse_inverse_associations, parse_metamodel)
from mc_openapi.doml_mc.xmi_parser.doml_model import (parse_doml_model,
                                                      parse_xmi_model)
from mc_openapi.doml_mc.z3encoding.im_encoding import (
    assert_im_associations, assert_im_attributes,
    def_elem_class_f_and_assert_classes, mk_attr_data_sort, mk_elem_sort_dict,
    mk_stringsym_sort_dict)
from mc_openapi.doml_mc.z3encoding.metamodel_encoding import (
    def_association_rel, def_attribute_rel, mk_association_sort_dict,
    mk_attribute_sort_dict, mk_class_sort_dict)
from mc_openapi.doml_mc.z3encoding.types import Refs

# %%
with open("../assets/doml_meta_v2.0.yaml") as mmf:
    mmdoc = yaml.load(mmf, yaml.Loader)
mm = parse_metamodel(mmdoc)

# %% [markdown]
# **You can change here the input DOML file**

# %%
# doml_document_path = "../../tests/doml/nginx-openstack_v2.0.domlx"
doml_document_path = "../../tests/doml/v2.0/nginx-openstack_v2.0_wrong_vm_iface.domlx"
# doml_document_path = "../../tests/doml/nginx-openstack_v2.0_wrong_iface_uniq.domlx"
# doml_document_path = "../../tests/doml/saas_no_https_rule.domlx"
# doml_document_path = "../../tests/doml/saas_https_no_attrs.domlx"
# doml_document_path = "../../tests/doml/openstack_template.domlx"

# %%
with open(doml_document_path, "rb") as xmif:
    doc = xmif.read()

im, _ = parse_doml_model(doc, DOMLVersion.V2_0)

# %% [markdown]
# We need to initialize each time the Solver context before iterating,
# since an unbound variable is an element, and elements are an EnumSort,
# and EnumSorts cannot be modified and depend on the solver context.
#
# The following code is stuff that is already present in the `IntermediateModelChecker`.

# %%
from typing import Dict

Context = Dict

# %%
from mc_openapi.doml_mc.intermediate_model.metamodel import get_mangled_attribute_defaults


def initialize_solver(
    unbound_elems_quantity: int = 0,
    unbound_values_quantity: int = 0,
    requirements: list = []
) -> Context:
    ctx = dict()
    
    ctx["solver"] = Solver()

    ctx["class_sort"], ctx["class_"] = mk_class_sort_dict(mm, ctx["solver"].ctx)
    ctx["assoc_sort"], ctx["assoc"] = mk_association_sort_dict(mm, ctx["solver"].ctx)
    ctx["attr_sort"], ctx["attr"] = mk_attribute_sort_dict(mm, ctx["solver"].ctx)
    ctx["str_sort"], ctx["str"] = mk_stringsym_sort_dict(im, mm, ctx["solver"].ctx)
    ctx["attr_data_sort"] = mk_attr_data_sort(ctx["str_sort"], ctx["solver"].ctx)

    ctx["unbound_elems"] = [f"unbound_elem_{i}" for i in range(unbound_elems_quantity)]

    # Takes a list of strings and creates an Enum out of 'em
    ctx["elem_sort"], ctx["elem"] = mk_elem_sort_dict(im, ctx["solver"].ctx, ctx["unbound_elems"])

    ub_val_names = [f"unbound_val_{i}" for i in range(unbound_values_quantity)]
    ctx["unbound_values"] = {
        name : ctx["attr_data_sort"].placeholder for name in ub_val_names
    }
    # Examples of values that can go in unbound_values:
    # ctx["attr_data_sort"].int(42), # ok
    # ctx["attr_data_sort"].bool(True), # ok
    # ctx["attr_data_sort"].str("x"), # cant do: it accept a ctx["str"][<str_key>] as input
    # Const("x", ctx["attr_data_sort"]) # cant do: it is a symbolic value that cannot be converted to a BoolRef expression

    ctx["elem_class_f"] = def_elem_class_f_and_assert_classes(
        im,
        ctx["solver"],
        ctx["elem_sort"],
        ctx["elem"],
        ctx["class_sort"],
        ctx["class_"]
    )
    
    # attr_rel :: (elem_sort, attr_sort, attr_data_sort) -> BoolRef
    ctx["attr_rel"] = def_attribute_rel(
        ctx["attr_sort"],
        ctx["elem_sort"],
        ctx["attr_data_sort"]
    )

    assert_im_attributes(
        ctx["attr_rel"],
        ctx["solver"],
        im,
        mm,
        ctx["elem"],
        ctx["attr_sort"],
        ctx["attr"],
        ctx["attr_data_sort"],
        ctx["str"]
    )

    # assoc_rel :: (elem_sort, assoc_sort, elem_sort) -> BoolRef
    ctx["assoc_rel"] = def_association_rel(
        ctx["assoc_sort"],
        ctx["elem_sort"]
    )
    
    assert_im_associations(
        ctx["assoc_rel"],
        ctx["solver"],
        {k: v for k, v in im.items() if k not in ctx["unbound_elems"]},
        ctx["elem"],
        ctx["assoc_sort"],
        ctx["assoc"],
    )

    # Add requirements
    for req in requirements:
        req(ctx)

    return ctx

# %%
initialize_solver()
print()
# Out:
# == None ==
# ForAll([a, d],
#        attribute(elem_140187603074384, a, d) ==
#        Or(And(a == commons_Property::key,
#               d == str(str_10_source_code)),
#           And(a == commons_SProperty::value,
#               d == str(str_22__usr_share_nginx))))
# == nginx ==
# ForAll([a, d],
#        attribute(elem_140187603074256, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_28_nginx)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder),
#           And(a ==
#               application_SoftwareComponent::isPersistent,
#               d == bool(False)),
#           And(a ==
#               application_SoftwareComponent::licenseCost,
#               d == placeholder),
#           And(a == application_SoftwareComponent::configFile,
#               d == placeholder)))
# == app ==
# ForAll([a, d],
#        attribute(elem_140187603072976, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_30_app)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder)))
# == net1 ==
# ForAll([a, d],
#        attribute(elem_140187603145616, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_9_net1)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder),
#           And(a == infrastructure_Network::protocol,
#               d == str(str_38_tcp_ip)),
#           And(a == infrastructure_Network::address_lb,
#               d == int(268435456)),
#           And(a == infrastructure_Network::address_ub,
#               d == int(268435711))))
# == v_img ==
# ForAll([a, d],
#        attribute(elem_140187603074896, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_32_v_img)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder),
#           And(a ==
#               infrastructure_ComputingNodeGenerator::uri,
#               d == placeholder),
#           And(a ==
#               infrastructure_ComputingNodeGenerator::kind,
#               d == str(str_15_script))))
# == ssh_key ==
# ForAll([a, d],
#        attribute(elem_140188808461264, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_17_ssh_key)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder),
#           And(a == infrastructure_KeyPair::user,
#               d == str(str_16_ubuntu)),
#           And(a == infrastructure_KeyPair::keyfile,
#               d == str(str_25__home_user1__ssh)),
#           And(a == infrastructure_KeyPair::algorithm,
#               d == str(str_26_rsa)),
#           And(a == infrastructure_KeyPair::bits,
#               d == int(4096))))
# == vm1 ==
# ForAll([a, d],
#        attribute(elem_140187603143120, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_31_vm1)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder),
#           And(a ==
#               infrastructure_ComputingNode::architecture,
#               d == placeholder),
#           And(a == infrastructure_ComputingNode::os,
#               d == str(str_40_ubuntu_20_04_3)),
#           And(a == infrastructure_ComputingNode::memory_mb,
#               d == placeholder),
#           And(a == infrastructure_ComputingNode::memory_kb,
#               d == placeholder),
#           And(a == infrastructure_ComputingNode::storage,
#               d == placeholder),
#           And(a == infrastructure_ComputingNode::cpu_count,
#               d == placeholder),
#           And(a == infrastructure_ComputingNode::cost,
#               d == placeholder),
#           And(a ==
#               infrastructure_VirtualMachine::sizeDescription,
#               d == placeholder)))
# == ag ==
# ForAll([a, d],
#        attribute(elem_140187603142416, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_20_ag)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder),
#           And(a == infrastructure_AutoScalingGroup::min,
#               d == int(1)),
#           And(a == infrastructure_AutoScalingGroup::max,
#               d == int(1)),
#           And(a ==
#               infrastructure_AutoScalingGroup::loadBalancer,
#               d == str(str_24_default))))
# == icmp ==
# ForAll([a, d],
#        attribute(elem_140187603145168, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_11_icmp)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder),
#           And(a == infrastructure_Rule::kind,
#               d == str(str_12_egress)),
#           And(a == infrastructure_Rule::protocol,
#               d == str(str_11_icmp)),
#           And(a == infrastructure_Rule::fromPort,
#               d == int(-1)),
#           And(a == infrastructure_Rule::toPort,
#               d == int(-1)),
#           And(a == infrastructure_Rule::cidr,
#               d == str(str_5_0_0_0_0_0))))
# == http ==
# ForAll([a, d],
#        attribute(elem_140187603145104, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_29_http)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder),
#           And(a == infrastructure_Rule::kind,
#               d == str(str_37_ingress)),
#           And(a == infrastructure_Rule::protocol,
#               d == str(str_18_tcp)),
#           And(a == infrastructure_Rule::fromPort,
#               d == int(80)),
#           And(a == infrastructure_Rule::toPort,
#               d == int(80)),
#           And(a == infrastructure_Rule::cidr,
#               d == str(str_5_0_0_0_0_0))))
# == https ==
# ForAll([a, d],
#        attribute(elem_140187603148048, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_8_https)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder),
#           And(a == infrastructure_Rule::kind,
#               d == str(str_37_ingress)),
#           And(a == infrastructure_Rule::protocol,
#               d == str(str_18_tcp)),
#           And(a == infrastructure_Rule::fromPort,
#               d == int(443)),
#           And(a == infrastructure_Rule::toPort,
#               d == int(443)),
#           And(a == infrastructure_Rule::cidr,
#               d == str(str_5_0_0_0_0_0))))
# == ssh ==
# ForAll([a, d],
#        attribute(elem_140187603152656, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_7_ssh)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder),
#           And(a == infrastructure_Rule::kind,
#               d == str(str_37_ingress)),
#           And(a == infrastructure_Rule::protocol,
#               d == str(str_18_tcp)),
#           And(a == infrastructure_Rule::fromPort,
#               d == int(22)),
#           And(a == infrastructure_Rule::toPort,
#               d == int(22)),
#           And(a == infrastructure_Rule::cidr,
#               d == str(str_5_0_0_0_0_0))))
# == sg ==
# ForAll([a, d],
#        attribute(elem_140187603144016, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_2_sg)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder)))
# == infra ==
# ForAll([a, d],
#        attribute(elem_140187603074448, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_36_infra)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder)))
# == None ==
# ForAll([a, d], Not(attribute(elem_140187603137040, a, d)))
# == config ==
# ForAll([a, d],
#        attribute(elem_140187603138000, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_35_config)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder)))
# == None ==
# ForAll([a, d],
#        attribute(elem_140187603131536, a, d) ==
#        Or(And(a == commons_Property::key,
#               d == str(str_34_name)),
#           And(a == commons_SProperty::value,
#               d == str(str_13_ostack2))))
# == concrete_net ==
# ForAll([a, d],
#        attribute(elem_140187603129936, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_39_concrete_net)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder),
#           And(a ==
#               concrete_ConcreteElement::configurationScript,
#               d == placeholder)))
# == None ==
# ForAll([a, d],
#        attribute(elem_140187603126800, a, d) ==
#        Or(And(a == commons_Property::key,
#               d == str(str_34_name)),
#           And(a == commons_SProperty::value,
#               d == str(str_40_ubuntu_20_04_3))))
# == concrete_vm_image ==
# ForAll([a, d],
#        attribute(elem_140187603124624, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_33_concrete_vm_imag)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder),
#           And(a ==
#               concrete_ConcreteElement::configurationScript,
#               d == placeholder)))
# == None ==
# ForAll([a, d],
#        attribute(elem_140187603125840, a, d) ==
#        Or(And(a == commons_Property::key,
#               d == str(str_4_vm_name)),
#           And(a == commons_SProperty::value,
#               d == str(str_14_nginx_host))))
# == None ==
# ForAll([a, d],
#        attribute(elem_140187603127440, a, d) ==
#        Or(And(a == commons_Property::key,
#               d == str(str_6_vm_flavor)),
#           And(a == commons_SProperty::value,
#               d == str(str_27_small))))
# == None ==
# ForAll([a, d],
#        attribute(elem_140187603127696, a, d) ==
#        Or(And(a == commons_Property::key,
#               d == str(str_3_vm_key_name)),
#           And(a == commons_SProperty::value,
#               d == str(str_21_user1))))
# == concrete_vm ==
# ForAll([a, d],
#        attribute(elem_140187603156752, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_1_concrete_vm)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder),
#           And(a ==
#               concrete_ConcreteElement::configurationScript,
#               d == placeholder)))
# == openstack ==
# ForAll([a, d],
#        attribute(elem_140187603155536, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_23_openstack)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder)))
# == con_infra ==
# ForAll([a, d],
#        attribute(elem_140187603153168, a, d) ==
#        Or(And(a == commons_DOMLElement::name,
#               d == str(str_0_con_infra)),
#           And(a == commons_DOMLElement::description,
#               d == placeholder)))
